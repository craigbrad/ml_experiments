# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Load Dataset
# This loads all of the house price data that is stored in a csv file

# %%
training_data = pd.read_csv('./house_price_data/train.csv')
training_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.set(style="darkgrid")
lot_area = training_data['LotArea']
sns.distplot(lot_area)

# %%
sns.countplot(x='YrSold', data=training_data)

# %%
sns.countplot(x='SaleType', data=training_data)

# %%
sns.countplot(x='SaleCondition', data=training_data)

# %%
sns.countplot(x='MoSold', data=training_data)

# %%
sns.relplot(x='MoSold', y='SalePrice', data=training_data)

# %%
sns.relplot(x='SaleCondition', y='SalePrice', data=training_data)

# %%
sns.relplot(x='LotShape', y='SalePrice', data=training_data)

# %%
sns.relplot(x='PoolArea', y='SalePrice', data=training_data)

# %%
sns.relplot(x='LotArea', y='SalePrice', data=training_data)

# %%
sns.relplot(x='MSZoning', y='SalePrice', data=training_data)

# %%
sns.relplot(x='LandContour', y='SalePrice', data=training_data)

# %%
sns.relplot(x='MSSubClass', y='SalePrice', data=training_data)
